# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Bloood pressure data.csv')

# %%
df.shape
# Out:
# (2000, 12)

# %%
df.head
# Out:
# <bound method NDFrame.head of       Patient_Number  Level_of_Hemoglobin   Age  BMI  Gender  Smoking  \
# 0                  1                11.28  34.0   23    Male        0
# 1                  2                 9.75  54.0   33    Male        0
# 2                  3                10.79  70.0   49    Male        0
# 3                  4                11.00  71.0   50    Male        0
# 4                  5                14.17  52.0   19    Male        0
# ...              ...                  ...   ...  ...     ...      ...
# 1995            1996                10.14  69.0   26    Male        1
# 1996            1997                11.77  24.0   45  Female        1
# 1997            1998                16.91  18.0   42    Male        0
# 1998            1999                11.15  46.0   45    Male        1
# 1999            2000                11.36  41.0   45    Male        0
#
#       Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of       Patient_Number  Level_of_Hemoglobin   Age  BMI  Gender  Smoking  \
# 0                  1                11.28  34.0   23    Male        0
# 1                  2                 9.75  54.0   33    Male        0
# 2                  3                10.79  70.0   49    Male        0
# 3                  4                11.00  71.0   50    Male        0
# 4                  5                14.17  52.0   19    Male        0
# ...              ...                  ...   ...  ...     ...      ...
# 1995            1996                10.14  69.0   26    Male        1
# 1996            1997                11.77  24.0   45  Female        1
# 1997            1998                16.91  18.0   42    Male        0
# 1998            1999                11.15  46.0   45    Male        1
# 1999            2000                11.36  41.0   45    Male        0
#
#       Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# ...

# %%
df.size
# Out:
# 24000

# %%
df.sample
# Out:
# <bound method NDFrame.sample of       Patient_Number  Level_of_Hemoglobin   Age  BMI  Gender  Smoking  \
# 0                  1                11.28  34.0   23    Male        0
# 1                  2                 9.75  54.0   33    Male        0
# 2                  3                10.79  70.0   49    Male        0
# 3                  4                11.00  71.0   50    Male        0
# 4                  5                14.17  52.0   19    Male        0
# ...              ...                  ...   ...  ...     ...      ...
# 1995            1996                10.14  69.0   26    Male        1
# 1996            1997                11.77  24.0   45  Female        1
# 1997            1998                16.91  18.0   42    Male        0
# 1998            1999                11.15  46.0   45    Male        1
# 1999            2000                11.36  41.0   45    Male        0
#
#       Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# ...

# %%
df.isnull().sum()
# Out:
# Patient_Number                   0
# Level_of_Hemoglobin              0
# Age                              5
# BMI                              0
# Gender                           0
# Smoking                          0
# Physical_activity                0
# salt_content_in_the_diet         0
# Level_of_Stress                  0
# Chronic_kidney_disease           0
# Adrenal_and_thyroid_disorders    0
# Blood_Pressure_Abnormality       0
# dtype: int64

# %%
df['Age'].var()
# Out:
# 291.9405318713031

# %%
da=df.fillna(value=df['Age'].std())

# %%
df.isnull().sum()
# Out:
# Patient_Number                   0
# Level_of_Hemoglobin              0
# Age                              5
# BMI                              0
# Gender                           0
# Smoking                          0
# Physical_activity                0
# salt_content_in_the_diet         0
# Level_of_Stress                  0
# Chronic_kidney_disease           0
# Adrenal_and_thyroid_disorders    0
# Blood_Pressure_Abnormality       0
# dtype: int64

# %%
da.isnull().sum()
# Out:
# Patient_Number                   0
# Level_of_Hemoglobin              0
# Age                              0
# BMI                              0
# Gender                           0
# Smoking                          0
# Physical_activity                0
# salt_content_in_the_diet         0
# Level_of_Stress                  0
# Chronic_kidney_disease           0
# Adrenal_and_thyroid_disorders    0
# Blood_Pressure_Abnormality       0
# dtype: int64

# %%
Y=df['Blood_Pressure_Abnormality']

# %%
X=df[0:12]

# %%
X
# Out:
#     Patient_Number  Level_of_Hemoglobin   Age  BMI  Gender  Smoking  \
# 0                1                11.28  34.0   23    Male        0
# 1                2                 9.75  54.0   33    Male        0
# 2                3                10.79  70.0   49    Male        0
# 3                4                11.00  71.0   50    Male        0
# 4                5                14.17  52.0   19    Male        0
# 5                6                11.64  23.0   48    Male        1
# 6                7                11.69  43.0   41  Female        0
# 7                8                12.70  48.0   20  Female        0
# 8                9                10.88  72.0   44  Female        0
# 9               10                14.56  40.0   44    Male        0
# 10              11                 8.58  70.0   28    Male        0
# 11              12                12.77  35.0   17  Female        0
#
#     Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# ...

# %%
X.drop('Blood_Pressure_Abnormality',axis=1)
# Out:
#     Patient_Number  Level_of_Hemoglobin   Age  BMI  Gender  Smoking  \
# 0                1                11.28  34.0   23    Male        0
# 1                2                 9.75  54.0   33    Male        0
# 2                3                10.79  70.0   49    Male        0
# 3                4                11.00  71.0   50    Male        0
# 4                5                14.17  52.0   19    Male        0
# 5                6                11.64  23.0   48    Male        1
# 6                7                11.69  43.0   41  Female        0
# 7                8                12.70  48.0   20  Female        0
# 8                9                10.88  72.0   44  Female        0
# 9               10                14.56  40.0   44    Male        0
# 10              11                 8.58  70.0   28    Male        0
# 11              12                12.77  35.0   17  Female        0
#
#     Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['BMI'],bins=8)
plt.title('BloodPressure')
plt.show()

# %%
plt.pie(df['Physical_activity'])
plt.title('Blood_Pressure')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
MinMax=MinMaxScaler()
d=da.drop('Gender',axis=1)
MinMax.fit(d)
Data=MinMax.transform(d)
Data
# Out:
# array([[0.00000000e+00, 3.36152220e-01, 2.92050467e-01, ...,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#        [5.00250125e-04, 1.74418605e-01, 6.37391702e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [1.00050025e-03, 2.84355180e-01, 9.13664691e-01, ...,
#         1.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#        ...,
#        [9.98999500e-01, 9.31289641e-01, 1.57774782e-02, ...,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00],
#        [9.99499750e-01, 3.22410148e-01, 4.99255208e-01, ...,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00],
#        [1.00000000e+00, 3.44608879e-01, 4.12919899e-01, ...,
#         1.00000000e+00, 0.00000000e+00, 1.00000000e+00]])

# %%
Scaler=StandardScaler()
Scaler.fit(d)
New_D=Scaler.transform(d)
New_D
# Out:
# array([[-1.731185  , -0.19670848, -0.72805903, ...,  0.9900495 ,
#          1.12017473,  1.01308561],
#        [-1.72945295, -0.89656771,  0.43989867, ..., -1.0100505 ,
#         -0.89271787, -0.98708341],
#        [-1.7277209 , -0.4208464 ,  1.37426483, ...,  0.9900495 ,
#         -0.89271787,  1.01308561],
#        ...,
#        [ 1.7277209 ,  2.37859055, -1.66242519, ...,  0.9900495 ,
#          1.12017473,  1.01308561],
#        [ 1.72945295, -0.25617364, -0.02728441, ..., -1.0100505 ,
#          1.12017473, -0.98708341],
#        [ 1.731185  , -0.16011453, -0.31927383, ...,  0.9900495 ,
#         -0.89271787,  1.01308561]])

# %%
from sklearn.preprocessing import

# %%
from sklearn.preprocessing import LabelEncoder
en=LabelEncoder()
en.fit(df1['Gender'])
d=en.transform(df1['Gender'])
d
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
f= df1['Gender'].value_counts(normalize=True)
f
# Out:
# Male      0.597
# Female    0.403
# Name: Gender, dtype: float64

# %%
da.loc[:,"{}_freq_encode".format('Gender')]=da['Gender'].map(f)
da
# Out:
#       Patient_Number  Level_of_Hemoglobin   Age  BMI  Gender  Smoking  \
# 0                  1                11.28  34.0   23    Male        0
# 1                  2                 9.75  54.0   33    Male        0
# 2                  3                10.79  70.0   49    Male        0
# 3                  4                11.00  71.0   50    Male        0
# 4                  5                14.17  52.0   19    Male        0
# ...              ...                  ...   ...  ...     ...      ...
# 1995            1996                10.14  69.0   26    Male        1
# 1996            1997                11.77  24.0   45  Female        1
# 1997            1998                16.91  18.0   42    Male        0
# 1998            1999                11.15  46.0   45    Male        1
# 1999            2000                11.36  41.0   45    Male        0
#
#       Physical_activity  salt_content_in_the_diet  Level_of_Stress  \
# ...
